# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('NeuroCardio.csv')
del df["BP value"]
df.head()
# Out:
#    Gender  Age  Heart rate(BPM)  Heart rate variability  Respiratory rate  \
# 0    Male   64               87                   68.77                12
# 1  Female   64               88                   83.06                26
# 2    Male   21               77                   27.95                24
# 3    Male   24               71                   68.80                14
# 4    Male   62               72                   35.48                13
#
#    Mental Fatigue level  Reaction time delay  Adrenaline  Cortisol level  \
# 0                  3.15               531.43        0.83           28.08
# 1                  8.52               428.84        2.71           12.95
# 2                  7.50               375.65        3.80           19.19
# 3                  3.11               318.27        0.71            8.72
# 4                  9.77               250.69        4.00           15.86
#
#   Stress level
# 0    Very High
# 1    Very High
# 2    Very High
# ...

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Heart rate(BPM)', 'Heart rate variability',
#        'Respiratory rate', 'Mental Fatigue level', 'Reaction time delay',
#        'Adrenaline', 'Cortisol level', 'Stress level'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Gender','Stress level']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
plt.figure(figsize=(12,7))
sns.countplot(x='Gender',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df['Heart rate variability'],color='red')

plt.subplot(1,2,2)
plt.hist(df['Reaction time delay'],color='blue')
# Out:
# (array([492., 511., 502., 524., 464., 488., 551., 467., 492., 509.]),
#  array([150.   , 194.991, 239.982, 284.973, 329.964, 374.955, 419.946,
#         464.937, 509.928, 554.919, 599.91 ]),
#  <BarContainer object of 10 artists>)

# %%
df.hist(figsize=(15,55),layout=(15,4), color='green')
plt.show()

# %%
df['Cortisol level'].hist(figsize=(10,5),color='yellow')
# Out:
# <Axes: >

# %%
sns.lineplot(df['Gender'], color='brown') # scatter, plot, triplot, stackplot
# Out:
# <Axes: ylabel='Gender'>

# %%
sns.violinplot(df['Mental Fatigue level'], color='purple')
# Out:
# <Axes: ylabel='Mental Fatigue level'>

# %%
df['Adrenaline'].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
sns.displot(df['Age'], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
sns.displot(df['Age'], color='coral') # residplot, scatterplot

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Stress level')
# Out:
# Stress level
# 2    73.46
# 0    24.86
# 1     1.68
# Name: count, dtype: float64
